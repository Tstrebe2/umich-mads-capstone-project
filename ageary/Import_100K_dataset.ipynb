# %% [markdown]
# <a href="https://colab.research.google.com/github/Tstrebe2/umich-mads-capstone-project/blob/main/tim-ft-densenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project' #Google Drive path
#path = '/home/ausgear' #Great Lakes
data_path = os.path.join(path, 'data/100K_dataset')
obj_path = os.path.join(path, 'python_objects')

# %%
#!/usr/bin/env python3
# Download the 56 zip files in Images_png in batches
import urllib.request
from datetime import datetime
import tarfile

# URLs for the zip files
links = [
    'https://nihcc.box.com/shared/static/vfk49d74nhbxq3nqjg0900w5nvkorp5c.gz',
    'https://nihcc.box.com/shared/static/i28rlmbvmfjbl8p2n3ril0pptcmcu9d1.gz',
    'https://nihcc.box.com/shared/static/f1t00wrtdk94satdfb9olcolqx20z2jp.gz',
	  'https://nihcc.box.com/shared/static/0aowwzs5lhjrceb3qp67ahp0rd1l1etg.gz',
    'https://nihcc.box.com/shared/static/v5e3goj22zr6h8tzualxfsqlqaygfbsn.gz',
	  'https://nihcc.box.com/shared/static/asi7ikud9jwnkrnkj99jnpfkjdes7l6l.gz',
	  'https://nihcc.box.com/shared/static/jn1b4mw4n6lnh74ovmcjb8y48h8xj07n.gz',
    'https://nihcc.box.com/shared/static/tvpxmn7qyrgl0w8wfh9kqfjskv6nmm1j.gz',
	  'https://nihcc.box.com/shared/static/upyy3ml7qdumlgk2rfcvlb9k6gvqq2pj.gz',
	  'https://nihcc.box.com/shared/static/l6nilvfa9cg3s28tqv1qc1olm3gnz54p.gz',
	  'https://nihcc.box.com/shared/static/hhq8fkdgvcari67vfhs7ppg2w6ni4jze.gz',
	  'https://nihcc.box.com/shared/static/ioqwiy20ihqwyr8pf4c24eazhh281pbu.gz'
]

for idx, link in enumerate(links):
    print(f'timestamp{datetime.now()}')
    fn = os.path.join(data_path,'images_%02d.tar.gz') % (idx+1)
    if not(os.path.isfile(fn)):
      print('Downloading '+fn+'...')
      urllib.request.urlretrieve(link, fn)  # download the zip file
      file = tarfile.open(fn)
      print('Extracting '+fn+'...')
      file.extractall(data_path)
      file.close()
      print('Deleting '+fn+'...')
      os.remove(fn)

print("Download complete. Please check the checksums")
# Out:
# timestamp2022-11-10 01:41:09.492882
# timestamp2022-11-10 01:41:09.633575
# Downloading /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_02.tar.gz...
# Extracting /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_02.tar.gz...
# Deleting /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_02.tar.gz...
# timestamp2022-11-10 01:50:23.730773
# Downloading /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_03.tar.gz...
# Extracting /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_03.tar.gz...
# Deleting /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_03.tar.gz...
# timestamp2022-11-10 01:58:51.408296
# Downloading /content/drive/MyDrive/SIADS_699_Capstone/Capstone_Team_Project/data/100K_dataset/images_04.tar.gz...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9a69b2f4c7a5> in <module>
#      26     if not(os.path.isfile(fn)):
#      27       print('Downloading '+fn+'...')
# ---> 28       urllib.request.urlretrieve(link, fn)  # download the zip file
#      29       file = tarfile.open(fn)
#      30       print('Extracting '+fn+'...')
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     463             # Amount is given, implement using readinto
#     464             b = bytearray(amt)
# --> 465             n = self.readinto(b)
#     466             return memoryview(b)[:n].tobytes()
#     467         else:
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     507         # connection, and the user is reading more bytes than will be provided
#     508         # (for example, reading in 1k chunks)
# --> 509         n = self.fp.readinto(b)
#     510         if not n and b:
#     511             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
